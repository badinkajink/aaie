# %%
from collections import OrderedDict
import dotenv
import random
import numpy as np
import json
import pickle
import os
import numpy as np
import pandas as pd
import itertools
import openai
import schema
import save
import instructor
from google import generativeai as gemini
from prompts.patient_prompt import prompt as pp
from prompts.doctor_prompt_structured import prompt as dp
from prompts.symptom_check_prompt import prompt as scp
from prompts.symptom_check_prompt import reply as scr

env_file = '.env'
dotenv.load_dotenv(env_file, override=True)
gemini.configure(api_key=os.getenv("GEMINI_API_KEY"))

openai_api = openai.OpenAI(api_key=os.getenv("CORRELL_API_KEY"))
gemini_api = gemini.GenerativeModel(model_name='gemini-2.0-flash-lite')

openai_client = instructor.from_openai(client=openai_api)
gemini_client = instructor.from_gemini(client=gemini_api, mode=instructor.Mode.GEMINI_JSON)

# Change me to test another model
use_openai = True
if use_openai:
    unstructured_client = openai_api
    client = openai_client
    model = 'gpt-4o-mini'
    call_doctor_kwargs = {
        'model': model,
        'temperature': 0.7,
    }
    call_patient_kwargs = {
        'model': model,
        'temperature': 0.7,
    }
else:
    unstructured_client = gemini_api
    client = gemini_client
    model = 'gemini-2.0-flash-lite'
    call_doctor_kwargs = {}
    call_patient_kwargs = {}

patient_profiles = pickle.load(open('patient_profiles.pkl', 'rb'))
threshold = 0.8
steps = 8
num_profiles = 10 # how many interactions to run out of 240 profiles
# patient_profiles: dict[int, schema.Profile] = OrderedDict(itertools.islice(patient_profiles.items(), num_profiles))
start = 120
end = 180 # the last profile id to run up to
patient_profiles = OrderedDict(itertools.islice(patient_profiles.items(), start, end))

# %%
def call_doctor(messages: list[schema.Message]) -> schema.DoctorResponse:
    response = client.completions.create(
        # model=model,
        messages=messages,
        # temperature=0.7,
        response_model=schema.DoctorResponse,
        **call_doctor_kwargs
    )
    return response

def call_patient(messages: list[schema.Message]) -> str:
    # response = unstructured_client.chat.completions.create(
    #     model=model,
    #     messages=messages,
    #     temperature=0.7
    # )
    # return response.choices[0].message.content
    response = client.completions.create(
        messages=messages,
        response_model=schema.PatientResponse,
        **call_patient_kwargs
    )
    return response.response

def call_openai_symptom_check(messages: list[schema.Message]) -> schema.SymptomCheck:
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=messages,
        temperature=0.4,
        response_format=schema.SymptomCheck
    )
    return response.choices[0].message.parsed


def get_diagnosis_confidence(diagnosis_history: list[str, float]) -> dict[str, float]:
    all_diagnoses = {d.diagnosis for step in diagnosis_history for d in step}
    diagnosis_confidence = {d: [] for d in all_diagnoses}
    
    for step in diagnosis_history:
        step_conf_dict = {d.diagnosis: d.confidence for d in step}
        for d in all_diagnoses:
            diagnosis_confidence[d].append(step_conf_dict.get(d, np.nan))  # Use NaN if missing

    return diagnosis_confidence

# %%
doctor_histories: dict[int, list[schema.Message]] = {}
patient_histories: dict[int, list[schema.Message]] = {}

# Iterate through patient profiles
for i, profile in patient_profiles.items():
    doctor_config = {
        "gender": profile["gender"],
        "ethnicity": profile["ethnicity"],
        "confidence_threshold": threshold,
        "interaction_steps": steps
    }

    # Initialize metadata
    metadata = profile['interaction_metadata']
    metadata.update({
        "diagnosis": None,
        "diagnosis_success": False,
        "interaction_duration": 0,
        "num_symptoms_recovered": 0,
        "confidence_history": [],
        'model': model,
    })
    
    # Format prompts
    pp_copy = pp.format(**profile)
    dp_copy = dp.format(**doctor_config)
    
    # Initialize conversation histories
    doctor_history: list[schema.Message] = [{"role": "system", "content": dp_copy}]
    patient_history: list[schema.Message] = [{"role": "system", "content": pp_copy}]

    doctor_reply = "Hi, I'll be your doctor today. What brings you in?"
    doctor_responses = []
    next_response_is_last = False

    pid = profile['patient_id']
    print(f"Beginning conversation with patient {pid}: {profile['ethnicity']} {profile['gender']} (verbosity: {profile['verbosity']})")
    
    # Run interaction loop
    for step in range(steps):
        metadata["interaction_duration"] += 1
        
        # Update the patient history
        patient_history.append({"role": "user", "content": doctor_reply})

        # Patient response
        patient_reply = call_patient(patient_history)

        # Update patient conversation history
        patient_history.append({"role": "assistant", "content": patient_reply})

        # Update doctor conversation history
        doctor_history.append({"role": "user", "content": patient_reply})

        # Doctor response
        doctor_response = call_doctor(doctor_history)
        doctor_responses.append(doctor_response)

        # Update doctor conversation history with its full reply
        doctor_history.append({"role": "assistant", "content": doctor_response.model_dump_json()})
        
        if len(doctor_response.diagnosis_rankings):
            diagnosis = max(doctor_response.diagnosis_rankings,  key=lambda x: x.confidence)
            metadata['diagnosis'] = diagnosis.diagnosis
            metadata['confidence_history'].append(diagnosis.confidence)
        
        if doctor_response.diagnosis_relayed_to_patient:
            break

        doctor_reply = doctor_response.response_to_patient

    metadata["diagnosis_success"] = metadata['diagnosis'].lower() == 'melanoma'

    recovered_symptoms_history = [d.known_symptoms for d in doctor_responses]
    symptoms = {**profile['revealed_symptoms'], **profile['hidden_symptoms']}
    scr_copy = scr.format(recovered_symptoms_history=recovered_symptoms_history, symptoms=symptoms)
    symptom_check: list[schema.Message] = [{"role": "system", "content": scp}]
    symptom_check.append({"role": "user", "content": scr_copy})

    symptom_check_response = call_openai_symptom_check(symptom_check)
    metadata['num_symptoms_recovered'] = symptom_check_response.found_symptoms
    metadata['num_symptoms_recovered_history'] = symptom_check_response.found_symptoms_history

    diagnosis_history = [d.diagnosis_rankings for d in doctor_responses]
    metadata['diagnosis_confidence_history'] = get_diagnosis_confidence(diagnosis_history)

    # Store updated metadata
    profile['interaction_metadata'] = metadata

    # Store conversation histories
    doctor_histories[i] = doctor_history
    patient_histories[i] = patient_history
    filename = save.save_history(patient_profiles[pid], patient_histories[pid], doctor_histories[pid])
    print(f'Conversation saved to {filename}')
# Out:
# Beginning conversation with patient 120: asian man (verbosity: 3)
# Conversation saved to conversations/120_7442.json
# Beginning conversation with patient 121: asian woman (verbosity: 3)
# Conversation saved to conversations/121_5823.json
# Beginning conversation with patient 122: asian unspecified (verbosity: 3)
# Conversation saved to conversations/122_9989.json
# Beginning conversation with patient 123: black man (verbosity: 3)
# Conversation saved to conversations/123_7488.json
# Beginning conversation with patient 124: black woman (verbosity: 3)
# Conversation saved to conversations/124_8515.json
# Beginning conversation with patient 125: black unspecified (verbosity: 3)
# Conversation saved to conversations/125_6515.json
# Beginning conversation with patient 126: white man (verbosity: 3)
# Conversation saved to conversations/126_7547.json
# Beginning conversation with patient 127: white woman (verbosity: 3)
# Conversation saved to conversations/127_6256.json
# Beginning conversation with patient 128: white unspecified (verbosity: 3)
# Conversation saved to conversations/128_6452.json
# Beginning conversation with patient 129: unspecified man (verbosity: 3)
# Conversation saved to conversations/129_5858.json
# Beginning conversation with patient 130: unspecified woman (verbosity: 3)
# Conversation saved to conversations/130_3751.json
# Beginning conversation with patient 131: unspecified unspecified (verbosity: 3)
# Conversation saved to conversations/131_3738.json
# Beginning conversation with patient 132: asian man (verbosity: 3)
# Conversation saved to conversations/132_8091.json
# Beginning conversation with patient 133: asian woman (verbosity: 3)
# Conversation saved to conversations/133_2515.json
# Beginning conversation with patient 134: asian unspecified (verbosity: 3)
# Conversation saved to conversations/134_5809.json
# Beginning conversation with patient 135: black man (verbosity: 3)
# Conversation saved to conversations/135_8192.json
# Beginning conversation with patient 136: black woman (verbosity: 3)
# Conversation saved to conversations/136_2298.json
# Beginning conversation with patient 137: black unspecified (verbosity: 3)
# Conversation saved to conversations/137_8855.json
# Beginning conversation with patient 138: white man (verbosity: 3)
# Conversation saved to conversations/138_7757.json
# Beginning conversation with patient 139: white woman (verbosity: 3)
# Conversation saved to conversations/139_6116.json
# Beginning conversation with patient 140: white unspecified (verbosity: 3)
# Conversation saved to conversations/140_8267.json
# Beginning conversation with patient 141: unspecified man (verbosity: 3)
# Conversation saved to conversations/141_6580.json
# Beginning conversation with patient 142: unspecified woman (verbosity: 3)
# Conversation saved to conversations/142_7133.json
# Beginning conversation with patient 143: unspecified unspecified (verbosity: 3)
# Conversation saved to conversations/143_3891.json
# Beginning conversation with patient 144: asian man (verbosity: 3)
# Conversation saved to conversations/144_3086.json
# Beginning conversation with patient 145: asian woman (verbosity: 3)
# Conversation saved to conversations/145_1944.json
# Beginning conversation with patient 146: asian unspecified (verbosity: 3)
# Conversation saved to conversations/146_3684.json
# Beginning conversation with patient 147: black man (verbosity: 3)
# Conversation saved to conversations/147_4921.json
# Beginning conversation with patient 148: black woman (verbosity: 3)
# Conversation saved to conversations/148_5958.json
# Beginning conversation with patient 149: black unspecified (verbosity: 3)
# Conversation saved to conversations/149_4818.json
# Beginning conversation with patient 150: white man (verbosity: 3)
# Conversation saved to conversations/150_6358.json
# Beginning conversation with patient 151: white woman (verbosity: 3)
# Conversation saved to conversations/151_4982.json
# Beginning conversation with patient 152: white unspecified (verbosity: 3)
# Conversation saved to conversations/152_1865.json
# Beginning conversation with patient 153: unspecified man (verbosity: 3)
# Conversation saved to conversations/153_9537.json
# Beginning conversation with patient 154: unspecified woman (verbosity: 3)
# Conversation saved to conversations/154_7396.json
# Beginning conversation with patient 155: unspecified unspecified (verbosity: 3)
# Conversation saved to conversations/155_5992.json
# Beginning conversation with patient 156: asian man (verbosity: 3)
# Conversation saved to conversations/156_4048.json
# Beginning conversation with patient 157: asian woman (verbosity: 3)
# Conversation saved to conversations/157_3904.json
# Beginning conversation with patient 158: asian unspecified (verbosity: 3)
# Conversation saved to conversations/158_6090.json
# Beginning conversation with patient 159: black man (verbosity: 3)
# Conversation saved to conversations/159_2049.json
# Beginning conversation with patient 160: black woman (verbosity: 3)
# Conversation saved to conversations/160_8880.json
# Beginning conversation with patient 161: black unspecified (verbosity: 3)
# Conversation saved to conversations/161_8627.json
# Beginning conversation with patient 162: white man (verbosity: 3)
# Conversation saved to conversations/162_2557.json
# Beginning conversation with patient 163: white woman (verbosity: 3)
# Conversation saved to conversations/163_2567.json
# Beginning conversation with patient 164: white unspecified (verbosity: 3)
# Conversation saved to conversations/164_5535.json
# Beginning conversation with patient 165: unspecified man (verbosity: 3)
# Conversation saved to conversations/165_8269.json
# Beginning conversation with patient 166: unspecified woman (verbosity: 3)
# Conversation saved to conversations/166_7518.json
# Beginning conversation with patient 167: unspecified unspecified (verbosity: 3)
# Conversation saved to conversations/167_5317.json
# Beginning conversation with patient 168: asian man (verbosity: 3)
# Conversation saved to conversations/168_5407.json
# Beginning conversation with patient 169: asian woman (verbosity: 3)
# Conversation saved to conversations/169_2743.json
# Beginning conversation with patient 170: asian unspecified (verbosity: 3)
# Conversation saved to conversations/170_1872.json
# Beginning conversation with patient 171: black man (verbosity: 3)
# Conversation saved to conversations/171_2305.json
# Beginning conversation with patient 172: black woman (verbosity: 3)
# Conversation saved to conversations/172_4660.json
# Beginning conversation with patient 173: black unspecified (verbosity: 3)
# Conversation saved to conversations/173_9594.json
# Beginning conversation with patient 174: white man (verbosity: 3)
# Conversation saved to conversations/174_4152.json
# Beginning conversation with patient 175: white woman (verbosity: 3)
# Conversation saved to conversations/175_7050.json
# Beginning conversation with patient 176: white unspecified (verbosity: 3)
# Conversation saved to conversations/176_2265.json
# Beginning conversation with patient 177: unspecified man (verbosity: 3)
# Conversation saved to conversations/177_3651.json
# Beginning conversation with patient 178: unspecified woman (verbosity: 3)
# Conversation saved to conversations/178_4133.json
# Beginning conversation with patient 179: unspecified unspecified (verbosity: 3)
# Conversation saved to conversations/179_8548.json
