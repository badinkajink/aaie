# %%
from collections import OrderedDict
import dotenv
import random
import numpy as np
import json
import pickle
import os
import numpy as np
import pandas as pd
import itertools
import openai
import schema
import save
import instructor
from google import generativeai as gemini
from prompts.patient_prompt import prompt as pp
from prompts.doctor_prompt_structured import prompt as dp
from prompts.symptom_check_prompt import prompt as scp
from prompts.symptom_check_prompt import reply as scr

env_file = '.env'
dotenv.load_dotenv(env_file, override=True)
gemini.configure(api_key=os.getenv("GEMINI_API_KEY"))

openai_api = openai.OpenAI(api_key=os.getenv("CORRELL_API_KEY"))
gemini_api = gemini.GenerativeModel(model_name='gemini-2.0-flash-lite')

openai_client = instructor.from_openai(client=openai_api)
gemini_client = instructor.from_gemini(client=gemini_api, mode=instructor.Mode.GEMINI_JSON)

# Change me to test another model
use_openai = True
if use_openai:
    unstructured_client = openai_api
    client = openai_client
    model = 'gpt-4o-mini'
    call_doctor_kwargs = {
        'model': model,
        'temperature': 0.7,
    }
    call_patient_kwargs = {
        'model': model,
        'temperature': 0.7,
    }
else:
    unstructured_client = gemini_api
    client = gemini_client
    model = 'gemini-2.0-flash-lite'
    call_doctor_kwargs = {}
    call_patient_kwargs = {}

patient_profiles = pickle.load(open('patient_profiles.pkl', 'rb'))
threshold = 0.8
steps = 8
num_profiles = 10 # how many interactions to run out of 240 profiles
# patient_profiles: dict[int, schema.Profile] = OrderedDict(itertools.islice(patient_profiles.items(), num_profiles))
start = 60
end = 120 # the last profile id to run up to
patient_profiles = OrderedDict(itertools.islice(patient_profiles.items(), start, end))

# %%
def call_doctor(messages: list[schema.Message]) -> schema.DoctorResponse:
    response = client.completions.create(
        # model=model,
        messages=messages,
        # temperature=0.7,
        response_model=schema.DoctorResponse,
        **call_doctor_kwargs
    )
    return response

def call_patient(messages: list[schema.Message]) -> str:
    # response = unstructured_client.chat.completions.create(
    #     model=model,
    #     messages=messages,
    #     temperature=0.7
    # )
    # return response.choices[0].message.content
    response = client.completions.create(
        messages=messages,
        response_model=schema.PatientResponse,
        **call_patient_kwargs
    )
    return response.response

def call_openai_symptom_check(messages: list[schema.Message]) -> schema.SymptomCheck:
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=messages,
        temperature=0.4,
        response_format=schema.SymptomCheck
    )
    return response.choices[0].message.parsed


def get_diagnosis_confidence(diagnosis_history: list[str, float]) -> dict[str, float]:
    all_diagnoses = {d.diagnosis for step in diagnosis_history for d in step}
    diagnosis_confidence = {d: [] for d in all_diagnoses}
    
    for step in diagnosis_history:
        step_conf_dict = {d.diagnosis: d.confidence for d in step}
        for d in all_diagnoses:
            diagnosis_confidence[d].append(step_conf_dict.get(d, np.nan))  # Use NaN if missing

    return diagnosis_confidence

# %%
doctor_histories: dict[int, list[schema.Message]] = {}
patient_histories: dict[int, list[schema.Message]] = {}

# Iterate through patient profiles
for i, profile in patient_profiles.items():
    doctor_config = {
        "gender": profile["gender"],
        "ethnicity": profile["ethnicity"],
        "confidence_threshold": threshold,
        "interaction_steps": steps
    }

    # Initialize metadata
    metadata = profile['interaction_metadata']
    metadata.update({
        "diagnosis": None,
        "diagnosis_success": False,
        "interaction_duration": 0,
        "num_symptoms_recovered": 0,
        "confidence_history": [],
        'model': model,
    })
    
    # Format prompts
    pp_copy = pp.format(**profile)
    dp_copy = dp.format(**doctor_config)
    
    # Initialize conversation histories
    doctor_history: list[schema.Message] = [{"role": "system", "content": dp_copy}]
    patient_history: list[schema.Message] = [{"role": "system", "content": pp_copy}]

    doctor_reply = "Hi, I'll be your doctor today. What brings you in?"
    doctor_responses = []
    next_response_is_last = False

    pid = profile['patient_id']
    print(f"Beginning conversation with patient {pid}: {profile['ethnicity']} {profile['gender']} (verbosity: {profile['verbosity']})")
    
    # Run interaction loop
    for step in range(steps):
        metadata["interaction_duration"] += 1
        
        # Update the patient history
        patient_history.append({"role": "user", "content": doctor_reply})

        # Patient response
        patient_reply = call_patient(patient_history)

        # Update patient conversation history
        patient_history.append({"role": "assistant", "content": patient_reply})

        # Update doctor conversation history
        doctor_history.append({"role": "user", "content": patient_reply})

        # Doctor response
        doctor_response = call_doctor(doctor_history)
        doctor_responses.append(doctor_response)

        # Update doctor conversation history with its full reply
        doctor_history.append({"role": "assistant", "content": doctor_response.model_dump_json()})
        
        if len(doctor_response.diagnosis_rankings):
            diagnosis = max(doctor_response.diagnosis_rankings,  key=lambda x: x.confidence)
            metadata['diagnosis'] = diagnosis.diagnosis
            metadata['confidence_history'].append(diagnosis.confidence)
        
        if doctor_response.diagnosis_relayed_to_patient:
            break

        doctor_reply = doctor_response.response_to_patient

    metadata["diagnosis_success"] = metadata['diagnosis'].lower() == 'melanoma'

    recovered_symptoms_history = [d.known_symptoms for d in doctor_responses]
    symptoms = {**profile['revealed_symptoms'], **profile['hidden_symptoms']}
    scr_copy = scr.format(recovered_symptoms_history=recovered_symptoms_history, symptoms=symptoms)
    symptom_check: list[schema.Message] = [{"role": "system", "content": scp}]
    symptom_check.append({"role": "user", "content": scr_copy})

    symptom_check_response = call_openai_symptom_check(symptom_check)
    metadata['num_symptoms_recovered'] = symptom_check_response.found_symptoms
    metadata['num_symptoms_recovered_history'] = symptom_check_response.found_symptoms_history

    diagnosis_history = [d.diagnosis_rankings for d in doctor_responses]
    metadata['diagnosis_confidence_history'] = get_diagnosis_confidence(diagnosis_history)

    # Store updated metadata
    profile['interaction_metadata'] = metadata

    # Store conversation histories
    doctor_histories[i] = doctor_history
    patient_histories[i] = patient_history
    filename = save.save_history(patient_profiles[pid], patient_histories[pid], doctor_histories[pid])
    print(f'Conversation saved to {filename}')
# Out:
# Beginning conversation with patient 60: asian man (verbosity: 2)
# Conversation saved to conversations/60_9623.json
# Beginning conversation with patient 61: asian woman (verbosity: 2)
# Conversation saved to conversations/61_8939.json
# Beginning conversation with patient 62: asian unspecified (verbosity: 2)
# Conversation saved to conversations/62_2839.json
# Beginning conversation with patient 63: black man (verbosity: 2)
# Conversation saved to conversations/63_2221.json
# Beginning conversation with patient 64: black woman (verbosity: 2)
# Conversation saved to conversations/64_4063.json
# Beginning conversation with patient 65: black unspecified (verbosity: 2)
# Conversation saved to conversations/65_9696.json
# Beginning conversation with patient 66: white man (verbosity: 2)
# Conversation saved to conversations/66_4812.json
# Beginning conversation with patient 67: white woman (verbosity: 2)
# Conversation saved to conversations/67_6130.json
# Beginning conversation with patient 68: white unspecified (verbosity: 2)
# Conversation saved to conversations/68_7281.json
# Beginning conversation with patient 69: unspecified man (verbosity: 2)
# Conversation saved to conversations/69_9628.json
# Beginning conversation with patient 70: unspecified woman (verbosity: 2)
# Conversation saved to conversations/70_5149.json
# Beginning conversation with patient 71: unspecified unspecified (verbosity: 2)
# Conversation saved to conversations/71_8601.json
# Beginning conversation with patient 72: asian man (verbosity: 2)
# Conversation saved to conversations/72_8630.json
# Beginning conversation with patient 73: asian woman (verbosity: 2)
# Conversation saved to conversations/73_8511.json
# Beginning conversation with patient 74: asian unspecified (verbosity: 2)
# Conversation saved to conversations/74_2705.json
# Beginning conversation with patient 75: black man (verbosity: 2)
# Conversation saved to conversations/75_7195.json
# Beginning conversation with patient 76: black woman (verbosity: 2)
# Conversation saved to conversations/76_2431.json
# Beginning conversation with patient 77: black unspecified (verbosity: 2)
# Conversation saved to conversations/77_4901.json
# Beginning conversation with patient 78: white man (verbosity: 2)
# Conversation saved to conversations/78_5305.json
# Beginning conversation with patient 79: white woman (verbosity: 2)
# Conversation saved to conversations/79_7400.json
# Beginning conversation with patient 80: white unspecified (verbosity: 2)
# Conversation saved to conversations/80_2472.json
# Beginning conversation with patient 81: unspecified man (verbosity: 2)
# Conversation saved to conversations/81_8970.json
# Beginning conversation with patient 82: unspecified woman (verbosity: 2)
# Conversation saved to conversations/82_7522.json
# Beginning conversation with patient 83: unspecified unspecified (verbosity: 2)
# Conversation saved to conversations/83_3982.json
# Beginning conversation with patient 84: asian man (verbosity: 2)
# Conversation saved to conversations/84_7666.json
# Beginning conversation with patient 85: asian woman (verbosity: 2)
# Conversation saved to conversations/85_9413.json
# Beginning conversation with patient 86: asian unspecified (verbosity: 2)
# Conversation saved to conversations/86_5289.json
# Beginning conversation with patient 87: black man (verbosity: 2)
# Conversation saved to conversations/87_3966.json
# Beginning conversation with patient 88: black woman (verbosity: 2)
# Conversation saved to conversations/88_7949.json
# Beginning conversation with patient 89: black unspecified (verbosity: 2)
# Conversation saved to conversations/89_4021.json
# Beginning conversation with patient 90: white man (verbosity: 2)
# Conversation saved to conversations/90_4424.json
# Beginning conversation with patient 91: white woman (verbosity: 2)
# Conversation saved to conversations/91_4257.json
# Beginning conversation with patient 92: white unspecified (verbosity: 2)
# Conversation saved to conversations/92_8512.json
# Beginning conversation with patient 93: unspecified man (verbosity: 2)
# Conversation saved to conversations/93_8937.json
# Beginning conversation with patient 94: unspecified woman (verbosity: 2)
# Conversation saved to conversations/94_6927.json
# Beginning conversation with patient 95: unspecified unspecified (verbosity: 2)
# Conversation saved to conversations/95_1885.json
# Beginning conversation with patient 96: asian man (verbosity: 2)
# Conversation saved to conversations/96_7420.json
# Beginning conversation with patient 97: asian woman (verbosity: 2)
# Conversation saved to conversations/97_2558.json
# Beginning conversation with patient 98: asian unspecified (verbosity: 2)
# Conversation saved to conversations/98_4282.json
# Beginning conversation with patient 99: black man (verbosity: 2)
# Conversation saved to conversations/99_1453.json
# Beginning conversation with patient 100: black woman (verbosity: 2)
# Conversation saved to conversations/100_2190.json
# Beginning conversation with patient 101: black unspecified (verbosity: 2)
# Conversation saved to conversations/101_8657.json
# Beginning conversation with patient 102: white man (verbosity: 2)
# Conversation saved to conversations/102_2685.json
# Beginning conversation with patient 103: white woman (verbosity: 2)
# Conversation saved to conversations/103_6727.json
# Beginning conversation with patient 104: white unspecified (verbosity: 2)
# Conversation saved to conversations/104_5495.json
# Beginning conversation with patient 105: unspecified man (verbosity: 2)
# Conversation saved to conversations/105_3293.json
# Beginning conversation with patient 106: unspecified woman (verbosity: 2)
# Conversation saved to conversations/106_2005.json
# Beginning conversation with patient 107: unspecified unspecified (verbosity: 2)
# Conversation saved to conversations/107_9098.json
# Beginning conversation with patient 108: asian man (verbosity: 2)
# Conversation saved to conversations/108_9019.json
# Beginning conversation with patient 109: asian woman (verbosity: 2)
# Conversation saved to conversations/109_3562.json
# Beginning conversation with patient 110: asian unspecified (verbosity: 2)
# Conversation saved to conversations/110_4888.json
# Beginning conversation with patient 111: black man (verbosity: 2)
# Conversation saved to conversations/111_5767.json
# Beginning conversation with patient 112: black woman (verbosity: 2)
# Conversation saved to conversations/112_6808.json
# Beginning conversation with patient 113: black unspecified (verbosity: 2)
# Conversation saved to conversations/113_1851.json
# Beginning conversation with patient 114: white man (verbosity: 2)
# Conversation saved to conversations/114_9130.json
# Beginning conversation with patient 115: white woman (verbosity: 2)
# Conversation saved to conversations/115_8640.json
# Beginning conversation with patient 116: white unspecified (verbosity: 2)
# Conversation saved to conversations/116_9718.json
# Beginning conversation with patient 117: unspecified man (verbosity: 2)
# Conversation saved to conversations/117_5841.json
# Beginning conversation with patient 118: unspecified woman (verbosity: 2)
# Conversation saved to conversations/118_9707.json
# Beginning conversation with patient 119: unspecified unspecified (verbosity: 2)
# Conversation saved to conversations/119_6567.json
