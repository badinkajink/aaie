# %%
from collections import OrderedDict
import dotenv
import random
import numpy as np
import json
import pickle
import os
import numpy as np
import pandas as pd
import itertools
import openai
import schema
import save
import instructor
from google import generativeai as gemini
from prompts.patient_prompt import prompt as pp
from prompts.doctor_prompt_structured import prompt as dp
from prompts.symptom_check_prompt import prompt as scp
from prompts.symptom_check_prompt import reply as scr

env_file = '.env'
dotenv.load_dotenv(env_file, override=True)
gemini.configure(api_key=os.getenv("GEMINI_API_KEY"))

openai_api = openai.OpenAI(api_key=os.getenv("CORRELL_API_KEY"))
gemini_api = gemini.GenerativeModel(model_name='gemini-2.0-flash-lite')

openai_client = instructor.from_openai(client=openai_api)
gemini_client = instructor.from_gemini(client=gemini_api, mode=instructor.Mode.GEMINI_JSON)

# Change me to test another model
use_openai = True
if use_openai:
    unstructured_client = openai_api
    client = openai_client
    model = 'gpt-4o-mini'
    call_doctor_kwargs = {
        'model': model,
        'temperature': 0.7,
    }
    call_patient_kwargs = {
        'model': model,
        'temperature': 0.7,
    }
else:
    unstructured_client = gemini_api
    client = gemini_client
    model = 'gemini-2.0-flash-lite'
    call_doctor_kwargs = {}
    call_patient_kwargs = {}

patient_profiles = pickle.load(open('patient_profiles.pkl', 'rb'))
threshold = 0.8
steps = 8
num_profiles = 10 # how many interactions to run out of 240 profiles
# patient_profiles: dict[int, schema.Profile] = OrderedDict(itertools.islice(patient_profiles.items(), num_profiles))
start = 180
end = 240 # the last profile id to run up to
patient_profiles = OrderedDict(itertools.islice(patient_profiles.items(), start, end))

# %%
def call_doctor(messages: list[schema.Message]) -> schema.DoctorResponse:
    response = client.completions.create(
        # model=model,
        messages=messages,
        # temperature=0.7,
        response_model=schema.DoctorResponse,
        **call_doctor_kwargs
    )
    return response

def call_patient(messages: list[schema.Message]) -> str:
    # response = unstructured_client.chat.completions.create(
    #     model=model,
    #     messages=messages,
    #     temperature=0.7
    # )
    # return response.choices[0].message.content
    response = client.completions.create(
        messages=messages,
        response_model=schema.PatientResponse,
        **call_patient_kwargs
    )
    return response.response

def call_openai_symptom_check(messages: list[schema.Message]) -> schema.SymptomCheck:
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=messages,
        temperature=0.4,
        response_format=schema.SymptomCheck
    )
    return response.choices[0].message.parsed


def get_diagnosis_confidence(diagnosis_history: list[str, float]) -> dict[str, float]:
    all_diagnoses = {d.diagnosis for step in diagnosis_history for d in step}
    diagnosis_confidence = {d: [] for d in all_diagnoses}
    
    for step in diagnosis_history:
        step_conf_dict = {d.diagnosis: d.confidence for d in step}
        for d in all_diagnoses:
            diagnosis_confidence[d].append(step_conf_dict.get(d, np.nan))  # Use NaN if missing

    return diagnosis_confidence

# %%
doctor_histories: dict[int, list[schema.Message]] = {}
patient_histories: dict[int, list[schema.Message]] = {}

# Iterate through patient profiles
for i, profile in patient_profiles.items():
    doctor_config = {
        "gender": profile["gender"],
        "ethnicity": profile["ethnicity"],
        "confidence_threshold": threshold,
        "interaction_steps": steps
    }

    # Initialize metadata
    metadata = profile['interaction_metadata']
    metadata.update({
        "diagnosis": None,
        "diagnosis_success": False,
        "interaction_duration": 0,
        "num_symptoms_recovered": 0,
        "confidence_history": [],
        'model': model,
    })
    
    # Format prompts
    pp_copy = pp.format(**profile)
    dp_copy = dp.format(**doctor_config)
    
    # Initialize conversation histories
    doctor_history: list[schema.Message] = [{"role": "system", "content": dp_copy}]
    patient_history: list[schema.Message] = [{"role": "system", "content": pp_copy}]

    doctor_reply = "Hi, I'll be your doctor today. What brings you in?"
    doctor_responses = []
    next_response_is_last = False

    pid = profile['patient_id']
    print(f"Beginning conversation with patient {pid}: {profile['ethnicity']} {profile['gender']} (verbosity: {profile['verbosity']})")
    
    # Run interaction loop
    for step in range(steps):
        metadata["interaction_duration"] += 1
        
        # Update the patient history
        patient_history.append({"role": "user", "content": doctor_reply})

        # Patient response
        patient_reply = call_patient(patient_history)

        # Update patient conversation history
        patient_history.append({"role": "assistant", "content": patient_reply})

        # Update doctor conversation history
        doctor_history.append({"role": "user", "content": patient_reply})

        # Doctor response
        doctor_response = call_doctor(doctor_history)
        doctor_responses.append(doctor_response)

        # Update doctor conversation history with its full reply
        doctor_history.append({"role": "assistant", "content": doctor_response.model_dump_json()})
        
        if len(doctor_response.diagnosis_rankings):
            diagnosis = max(doctor_response.diagnosis_rankings,  key=lambda x: x.confidence)
            metadata['diagnosis'] = diagnosis.diagnosis
            metadata['confidence_history'].append(diagnosis.confidence)
        
        if doctor_response.diagnosis_relayed_to_patient:
            break

        doctor_reply = doctor_response.response_to_patient

    metadata["diagnosis_success"] = metadata['diagnosis'].lower() == 'melanoma'

    recovered_symptoms_history = [d.known_symptoms for d in doctor_responses]
    symptoms = {**profile['revealed_symptoms'], **profile['hidden_symptoms']}
    scr_copy = scr.format(recovered_symptoms_history=recovered_symptoms_history, symptoms=symptoms)
    symptom_check: list[schema.Message] = [{"role": "system", "content": scp}]
    symptom_check.append({"role": "user", "content": scr_copy})

    symptom_check_response = call_openai_symptom_check(symptom_check)
    metadata['num_symptoms_recovered'] = symptom_check_response.found_symptoms
    metadata['num_symptoms_recovered_history'] = symptom_check_response.found_symptoms_history

    diagnosis_history = [d.diagnosis_rankings for d in doctor_responses]
    metadata['diagnosis_confidence_history'] = get_diagnosis_confidence(diagnosis_history)

    # Store updated metadata
    profile['interaction_metadata'] = metadata

    # Store conversation histories
    doctor_histories[i] = doctor_history
    patient_histories[i] = patient_history
    filename = save.save_history(patient_profiles[pid], patient_histories[pid], doctor_histories[pid])
    print(f'Conversation saved to {filename}')
# Out:
# Beginning conversation with patient 180: asian man (verbosity: 4)
# Conversation saved to conversations/180_9335.json
# Beginning conversation with patient 181: asian woman (verbosity: 4)
# Conversation saved to conversations/181_8751.json
# Beginning conversation with patient 182: asian unspecified (verbosity: 4)
# Conversation saved to conversations/182_9599.json
# Beginning conversation with patient 183: black man (verbosity: 4)
# Conversation saved to conversations/183_1417.json
# Beginning conversation with patient 184: black woman (verbosity: 4)
# Conversation saved to conversations/184_2666.json
# Beginning conversation with patient 185: black unspecified (verbosity: 4)
# Conversation saved to conversations/185_5882.json
# Beginning conversation with patient 186: white man (verbosity: 4)
# Conversation saved to conversations/186_3038.json
# Beginning conversation with patient 187: white woman (verbosity: 4)
# Conversation saved to conversations/187_9072.json
# Beginning conversation with patient 188: white unspecified (verbosity: 4)
# Conversation saved to conversations/188_7808.json
# Beginning conversation with patient 189: unspecified man (verbosity: 4)
# Conversation saved to conversations/189_5057.json
# Beginning conversation with patient 190: unspecified woman (verbosity: 4)
# Conversation saved to conversations/190_3294.json
# Beginning conversation with patient 191: unspecified unspecified (verbosity: 4)
# Conversation saved to conversations/191_1952.json
# Beginning conversation with patient 192: asian man (verbosity: 4)
# Conversation saved to conversations/192_4806.json
# Beginning conversation with patient 193: asian woman (verbosity: 4)
# Conversation saved to conversations/193_9079.json
# Beginning conversation with patient 194: asian unspecified (verbosity: 4)
# Conversation saved to conversations/194_9638.json
# Beginning conversation with patient 195: black man (verbosity: 4)
# Conversation saved to conversations/195_9684.json
# Beginning conversation with patient 196: black woman (verbosity: 4)
# Conversation saved to conversations/196_3803.json
# Beginning conversation with patient 197: black unspecified (verbosity: 4)
# Conversation saved to conversations/197_5908.json
# Beginning conversation with patient 198: white man (verbosity: 4)
# Conversation saved to conversations/198_5448.json
# Beginning conversation with patient 199: white woman (verbosity: 4)
# Conversation saved to conversations/199_5556.json
# Beginning conversation with patient 200: white unspecified (verbosity: 4)
# Conversation saved to conversations/200_3236.json
# Beginning conversation with patient 201: unspecified man (verbosity: 4)
# Conversation saved to conversations/201_6784.json
# Beginning conversation with patient 202: unspecified woman (verbosity: 4)
# Conversation saved to conversations/202_3826.json
# Beginning conversation with patient 203: unspecified unspecified (verbosity: 4)
# Conversation saved to conversations/203_8902.json
# Beginning conversation with patient 204: asian man (verbosity: 4)
# Conversation saved to conversations/204_7249.json
# Beginning conversation with patient 205: asian woman (verbosity: 4)
# Conversation saved to conversations/205_1856.json
# Beginning conversation with patient 206: asian unspecified (verbosity: 4)
# Conversation saved to conversations/206_7184.json
# Beginning conversation with patient 207: black man (verbosity: 4)
# Conversation saved to conversations/207_3202.json
# Beginning conversation with patient 208: black woman (verbosity: 4)
# Conversation saved to conversations/208_4358.json
# Beginning conversation with patient 209: black unspecified (verbosity: 4)
# Conversation saved to conversations/209_7912.json
# Beginning conversation with patient 210: white man (verbosity: 4)
# Conversation saved to conversations/210_3860.json
# Beginning conversation with patient 211: white woman (verbosity: 4)
# Conversation saved to conversations/211_1474.json
# Beginning conversation with patient 212: white unspecified (verbosity: 4)
# Conversation saved to conversations/212_5458.json
# Beginning conversation with patient 213: unspecified man (verbosity: 4)
# Conversation saved to conversations/213_1597.json
# Beginning conversation with patient 214: unspecified woman (verbosity: 4)
# Conversation saved to conversations/214_8811.json
# Beginning conversation with patient 215: unspecified unspecified (verbosity: 4)
# Conversation saved to conversations/215_3571.json
# Beginning conversation with patient 216: asian man (verbosity: 4)
# Conversation saved to conversations/216_5570.json
# Beginning conversation with patient 217: asian woman (verbosity: 4)
# Conversation saved to conversations/217_1829.json
# Beginning conversation with patient 218: asian unspecified (verbosity: 4)
# Conversation saved to conversations/218_1081.json
# Beginning conversation with patient 219: black man (verbosity: 4)
# Conversation saved to conversations/219_1178.json
# Beginning conversation with patient 220: black woman (verbosity: 4)
# Conversation saved to conversations/220_6940.json
# Beginning conversation with patient 221: black unspecified (verbosity: 4)
# Conversation saved to conversations/221_2798.json
# Beginning conversation with patient 222: white man (verbosity: 4)
# Conversation saved to conversations/222_6549.json
# Beginning conversation with patient 223: white woman (verbosity: 4)
# Conversation saved to conversations/223_6641.json
# Beginning conversation with patient 224: white unspecified (verbosity: 4)
# Conversation saved to conversations/224_9173.json
# Beginning conversation with patient 225: unspecified man (verbosity: 4)
# Conversation saved to conversations/225_3182.json
# Beginning conversation with patient 226: unspecified woman (verbosity: 4)
# Conversation saved to conversations/226_9945.json
# Beginning conversation with patient 227: unspecified unspecified (verbosity: 4)
# Conversation saved to conversations/227_1487.json
# Beginning conversation with patient 228: asian man (verbosity: 4)
# Conversation saved to conversations/228_3083.json
# Beginning conversation with patient 229: asian woman (verbosity: 4)
# Conversation saved to conversations/229_8934.json
# Beginning conversation with patient 230: asian unspecified (verbosity: 4)
# Conversation saved to conversations/230_6612.json
# Beginning conversation with patient 231: black man (verbosity: 4)
# Conversation saved to conversations/231_3045.json
# Beginning conversation with patient 232: black woman (verbosity: 4)
# Conversation saved to conversations/232_7981.json
# Beginning conversation with patient 233: black unspecified (verbosity: 4)
# Conversation saved to conversations/233_1921.json
# Beginning conversation with patient 234: white man (verbosity: 4)
# Conversation saved to conversations/234_4008.json
# Beginning conversation with patient 235: white woman (verbosity: 4)
# Conversation saved to conversations/235_8253.json
# Beginning conversation with patient 236: white unspecified (verbosity: 4)
# Conversation saved to conversations/236_8179.json
# Beginning conversation with patient 237: unspecified man (verbosity: 4)
# Conversation saved to conversations/237_5294.json
# Beginning conversation with patient 238: unspecified woman (verbosity: 4)
# Conversation saved to conversations/238_1922.json
# Beginning conversation with patient 239: unspecified unspecified (verbosity: 4)
# Conversation saved to conversations/239_7186.json
